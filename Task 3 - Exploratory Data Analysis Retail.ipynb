# %% [markdown]
# # Importing Library

# %% [markdown]
# ## The SparksFoundation- GRIP internship #JAN2021

# %% [markdown]
# # Task 3 - Exploratory Data Analysis Retail Superstore

# %% [markdown]
# ### Task :
#     * As a business manager, try to find out the weak areas where you can work to make more profit.
#     * What all business problems you can derive by exploring the data?
#     * Dash Boards- explaining the charts and interpretations

# %% [markdown]
# # By Upendra Raut

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the data set
df = pd.read_csv('C:\\Users\\intel\\Desktop\\SampleSuperstore.csv') 
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#displaying the number of rows and number of columns
df.shape
# Out:
# (9994, 13)

# %%
#displaying the data types
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
#describing statistical information about the dataset
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#summary of a DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 702.8+ KB

# %% [markdown]
# # Data Cleaning

# %%
#dropping unnecessary column
#finding the count of duplicate values in a specific Column.
df.duplicated(subset='Country').sum()
# Out:
# 9993

# %%
#since there is only one state we can drop it
df.drop(columns=['Country'],inplace=True)

# %%
#finding the duplicate data
df.duplicated().sum()
# Out:
# 17

# %%
#removing those duplicate data
df.drop_duplicates(inplace=True)

# %%
#checking if there still exist any duplicate data
df.duplicated().sum()
# Out:
# 0

# %%
#Finding the number of missing values in each column.
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#checking for null values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#displaying the number of rows and number of columns
df.shape
# Out:
# (9977, 12)

# %% [markdown]
# # VISUALISING DATA

# %%
#visualising the count of Ship Mode variable
plt.figure(figsize=(10,5))
sns.countplot(x="Ship Mode",data=df)
plt.show()

# %% [markdown]
# Standard Class has the highest count in ship mode .

# %%
#visualizing the count of Segment variable
plt.figure(figsize=(10,5))
sns.countplot(x="Segment",data=df)
plt.show()

# %% [markdown]
# Consumer Segment has the largest count.

# %%
#visualizing the count of State varaibale
plt.figure(figsize=(20,10))
sns.countplot(x="State",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Our customer base is huge in California,New York,Texas etc. Virginia,Wyoming,North Dakota and other states on the right of the graph need to improve their customer base.

# %%
#visualizing the count of Region varaibale
plt.figure(figsize=(10,5))
sns.countplot(x="Region",data=df)
plt.show()

# %% [markdown]
# West Region is the highest contributing region to the business followed by East.South is the least contributing region to the business.

# %%
#visualizing the count of Sub-Category varaibale
plt.figure(figsize=(10,5))
sns.countplot(x="Sub-Category",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Huge number of our customers buy binders and papers from us. We need to work on the quality and sales of our copiers, machines and other subcategories with low count.

# %%
#visualizing the count of Sub-Category varaibale
plt.figure(figsize=(10,5))
sns.countplot(x="Category",data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Office Supplies has highest count and technology has lowest.

# %% [markdown]
# # Checking how different variables are related to our profit

# %%
# Profit vs State
plt.figure(figsize=(35,15))
plt.bar(df['State'],df['Profit'])
plt.xlabel('State')
plt.ylabel('Profit')
plt.title('Profit Vs State')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The graph shows the range of profit made my each state. From here we can see that North Carolina ,Texas,Illinoise Chino are the states making severe losses.

# %% [markdown]
# Let's find out the total profit a state is making

# %%
#Total Profit vs States
plt.figure(figsize=(20,10))
state=df.groupby(["State"])["Profit"].sum()
state.sort_values(ascending=False,inplace=True)
state.plot.bar()
plt.show()

# %% [markdown]
# California has the highest profit. The states like New York , Washington etc are showing good profit.But some states like Texas , Ohio are incurring overall loss even though the paticipation was more in these states.

# %%
#Total Profit vs Ship Mode
plt.figure(figsize=(10,5))
ship=df.groupby(["Ship Mode"])["Profit"].sum()
ship.sort_values(ascending=False,inplace=True)
ship.plot.bar()
plt.show()

# %% [markdown]
# Standard class is showing highest total profit and it was also preffered by most of our customers. Same Day Delivery is making least total profit, this maybe because they also has least count among the ship modes. All the ship modes has positive total profit. This means the company is definitely making overall profit. And that overall profit is the sum of all the total profits made by each ship mode.

# %%
#Total Profit vs Segment
plt.figure(figsize=(10,5))
segment=df.groupby(["Segment"])["Profit"].sum()
segment.sort_values(ascending=False,inplace=True)
segment.plot.bar()
plt.show()

# %% [markdown]
# Consumer Segment is making the highest total profit followed by Corporate.

# %%
#Total Profit vs City  
plt.figure(figsize=(10,5))
data=df.groupby(["City"])["Profit"].sum()
df1=data[data>10000]
df1.sort_values(ascending=False,inplace=True)
df1.plot.bar()#plotting the graphs of only those cities with total profit more than 10000
plt.show()
plt.figure(figsize=(10,5))
df2=data[data<-2000]
df2.sort_values(ascending=False,inplace=True)
df2.plot.bar()#plotting the graphs of only those cities with total profit less than -2000
plt.show()

# %% [markdown]
# The most profit making cities are New York City , Los Angeles and Seattle. Philandelphia,Huston,San Antonio,Lancster and Chicago are makin huge losses.

# %%
#Total Profit Vs Category 
plt.figure(figsize=(10,5))
category=df.groupby(["Category"])["Profit"].sum()
category.sort_values(ascending=False,inplace=True)
category.plot.bar()
plt.show()

# %% [markdown]
# Technology is making maximum total profit despite of having lowest counts. This is because per unit technology selling is the most profitable thing.

# %%
#Total Profit Vs Sub-Category
plt.figure(figsize=(10,5))
scategory=df.groupby(["Sub-Category"])["Profit"].sum()
scategory.sort_values(ascending=False,inplace=True)
scategory.plot.bar()
plt.show()

# %% [markdown]
# Copiers are making maximum total profit despite of having lowest count as it belongs to technology category. It means our company should work on the sales of our copiers .

# %%
#Profit and sales 
plt.figure(figsize=(10,5))
sns.scatterplot(df['Sales'],df['Profit'])

# %% [markdown]
# We can see that upto a certain point with the increase in sales  profit increases but after that there comes a range of sales where increasing sales is not helping much with profit. But once that range is crossed increasing sales, increases profit. So, we must try that our total sales shouldn't fall in that uncertain range.

# %%
#Total Profit vs Region 
plt.figure(figsize=(10,5))
region=df.groupby(["Region"])["Profit"].sum()
region.sort_values(ascending=False,inplace=True)
region.plot.bar()
plt.show()

# %% [markdown]
# West is making maximum total profit and also had maximum count. While central region is struggling in both total profit and counts. We need to focus on central and south region.

# %%
#heatmap to show the correlation of the dataset
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# The discount is inversely proportional to the profit as well as sales, so the idea of increasing discounts to increase sales or sales quantity can be discarded easily. The correlation between Profit and sales is significant .With the increase in sales, profit increases. There is also positive correlation between sales and quantity.

# %% [markdown]
# To conclude:
# 1. Our central region business is struggling in both total profit and counts. We need to focus on central and south region also.
# 2. We need to improve our business permormance in some states like Texas and Ohio which are incurring overall loss even though the paticipation is high in these states.
# 3. Standard class is showing highest total profit and it was also preffered by most of our customers. Same Day Delivery is making least total profit, this maybe because they also has least count among the ship modes. So, it doesn't seem as much of a problem.
# 4. Consumer Segment is making the highest total profit followed by Corporate. And home office is making least profit which also seems okay.
# 5. Philandelphia,Huston,San Antonio,Lancster and Chicago are cities making huge losses. They need our attention.
# 6. Technology is making maximum total profit despite of having lowest counts. This maybe because per unit technology selling is the most profitable thing.
# 7. Copiers are making maximum total profit despite of having lowest count as it belongs to technology category. It means our company should work on the sales of our copiers .
# 8. Increasing sales is always safe and helpful in increasing profit unless it falls in that uncertain range of sales where profit is not following the increasing trend.
# 9. The discount is inversely proportional to the profit as well as sales, so the idea of increasing discounts to increase sales or sales quantity can be discarded easily.
